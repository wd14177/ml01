# %%
import pandas as pd


df = pd.read_csv('data/rider_data.csv')
df.head()
# Out:
#    Distance_km  Riders_Available  Weather_Index  Rush_Hour   Time_min
# 0     2.934511                19              6          0  24.017860
# 1     6.679643                16              2          0  28.422919
# 2     5.257961                20              7          0  31.826773
# 3     4.391280                28              5          0  20.906637
# 4     1.514121                23              4          0   6.290465

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

X_train,X_test,y_train,y_test = train_test_split( df.drop('Time_min',axis=1) , df['Time_min'], random_state=3333)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (750, 4)
# (250, 4)
# (750,)
# (250,)

# %%
model = LinearRegression()

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)
pred
# Out:
# array([25.01843854, 10.48012383, 15.1157771 , 46.08180671, 48.60436677,
#        24.1896645 ,  9.76832107, 34.74839388, 17.67706247, 53.7882989 ,
#        19.4248271 , 27.64204823, 30.37279141, 26.33086772, 36.819484  ,
#        31.81592172, 46.64018979, 19.3022175 , 26.36891267,  7.0525249 ,
#        27.16597526, 26.2623304 , 15.36456386,  4.90563613, 25.30667892,
#        33.04654936, 38.10330387, 19.92710632, 34.65607035, 42.44707552,
#        38.70086148, 35.17255163, 10.24253864, 36.16048366,  5.10110111,
#        27.20816263, 23.02543621, 21.30621436, 19.21278098, 24.6104503 ,
#        27.87415925, 10.1608238 , 33.53006714, 18.78120065,  4.97800397,
#        19.87089177, 26.93716342, 24.08262315, 29.69251372, 27.79158747,
#        27.53879572, 42.00725618, 27.21316041, 28.18635775, 29.85168555,
#        46.08998092, 12.41696325, 26.70518731, 12.06346009, 27.07558395,
#        43.97280784, 40.57279131, 45.28475342, 26.116674  , 34.19259589,
#        41.94837004, 38.27490476, 30.4284245 , 38.58996818, 29.14222837,
#        29.93111253, 43.11228547,  5.71924337, 34.24819799, 26.84974276,
#        25.56988922, 18.7013647 , 15.26792721, 21.4133725 , 29.10563275,
#        21.96196572, 15.05167015, 17.45273345, 21.37721406, 16.33409812,
#        14.15669093, 22.99176703, 10.57308919, 22.1092439 , 17.23683622,
#        33.73978003, 24.34022859, 23.63668968, 20.19171718, 23.05172487,
#        32.94457641, 23.55050283, 24.59559494, 28.41641204, 44.46113147,
#        33.14166059, 26.80155436, 22.06922733, 39.46145512, 37.2723215 ,
#        45.30428675, 27.62118201, 34.21593664, 15.38881702, 45.33220435,
#        42.93311709, 21.61968617, 28.35042605, 28.01892426, 31.47839514,
#        26.45937675, 37.81040973, 31.26475465, 41.96409301, 31.02301565,
#        21.73114848, 31.79937237, 20.7770309 , 23.33041027, 31.5143531 ,
#        28.98368432, 42.07683611, 35.87608473, 14.36223548, 15.38902685,
#        18.79717384, 23.6585204 , 34.58100184, 14.7510193 , 10.38146241,
#        23.18625867, 32.97243795, 34.76684477, 30.78742168, 24.95770709,
#         1.29036363, 17.64083277, 33.89527147, 26.31738668, 15.36846422,
#        32.83359035, 29.23893767, 23.14019245, 43.37592685, 27.66003276,
#        20.12710902, 23.2094907 , 37.38829882, 21.15087129, 39.90721736,
#         2.63555741, 19.84835662, 39.67442537, 38.75520896, 33.81994449,
#        10.37316971, 11.9767344 , 24.95834714, 41.07556925, 30.93604661,
#        42.64647728, 29.52013324, 29.31544744, 37.34011435, 12.44153154,
#        31.48853028, 38.12563143, 38.15410386, 14.66345606, 38.71479952,
#         4.50890982, 32.14906315, 31.65286949, 32.78990166, 26.25906511,
#         5.14056259, 14.79421801, 31.99773248, 13.02140365, 31.44053319,
#        25.12802148, 25.86459005, 32.30736942, 40.13324006, 26.79923057,
#        13.08762655, 22.3741056 , 30.61967809, 27.0976271 , 22.14930192,
#        20.00600202, 14.77867105, 22.30488441, 43.73411494, 42.36485681,
#        41.35336248, 36.4859325 , 23.77130357, 41.52526619, 17.51946574,
#        44.55540045, 35.33874406, 32.32546343, 35.20969358, 10.77691351,
#        13.08759752, 41.07839329, 28.2218339 , 34.24213711, 40.67023156,
#        25.91390831, 16.34514971, 28.24943421, 15.14071073, 20.32331464,
#        22.95848593, 19.63340642, 33.61491704, 27.97976236, 14.06895199,
#        21.54897676,  4.11890945, 17.08512259, 25.93024194, 33.96366127,
#        13.68731569, 32.39060977, 17.48135914, 49.71300897, 56.57844177,
#        31.39028065, 38.07660994, 29.70503979, 41.77498681, 36.50343889,
#        25.32135391, 13.02907428, 31.02908184, 35.64944022, 35.3702655 ,
#        37.05408826, 16.99200811, 13.99285456, 30.45106009, 15.18657174])

# %%
mae = mean_absolute_error(y_test,pred)
mae
# Out:
# 2.3817835704731167

# %%
model.coef_

print(' 회귀계수 -  Coefficient')
coef_df = pd.DataFrame({
    'feature' : ['Distance_km','Riders_Available','Weather_Index','Rush_Hour'],
    'Coef' : model.coef_
})
coef_df
# Out:
#  회귀계수 -  Coefficient
#             feature       Coef
# 0       Distance_km   3.967227
# 1  Riders_Available  -0.508047
# 2     Weather_Index   1.477702
# 3         Rush_Hour  10.224068

# %%
print('절편',model.intercept_)
# Out:
# 절편 10.24753491967267

# %%
#평가
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import numpy as np

mae = mean_absolute_error(y_test,pred)
mse = mean_squared_error(y_test,pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,pred)

print('MAE : ',mae)
print('MSE : ',mse)
print('RMSE : ',rmse)
print('r2 : ',r2)
# Out:
# MAE :  2.3817835704731167
# MSE :  8.828727788282874
# RMSE :  2.9713175172443074
# r2 :  0.9281633439010146

# %% [markdown]
# # 회귀 모델 평가 지표 정리 (MAE / MSE / RMSE / R²)
#
# ---
#
# # MAE (Mean Absolute Error)
#
# ## 정의
# 예측값과 실제값 차이의 **절댓값 평균**
#
# ## 공식
# MAE = (1/n) Σ |y_true - y_pred|
#
# ## 특징
# - 해석이 매우 쉬움
# - 단위가 원래 값과 동일
# - 이상치 영향이 비교적 적음
#
# ## 한 줄 설명
# 👉 평균적으로 얼마나 틀렸는지
#
# ---
#
# # 2️⃣ MSE (Mean Squared Error)
#
# ## 정의
# 오차를 **제곱해서 평균**
#
# ## 공식
# MSE = (1/n) Σ (y_true - y_pred)²
#
# ## 특징
# - 큰 오차를 더 크게 벌점
# - 이상치에 매우 민감
# - 단위가 제곱 단위가 됨
#
# ## 한 줄 설명
# 👉 큰 실수를 더 크게 혼내는 지표
#
# ---
#
# #  3️⃣ RMSE (Root Mean Squared Error)
#
# ## 정의
# MSE에 **제곱근**을 씌운 값
#
# ## 공식
# RMSE = √MSE
#
# ## 특징
# - 단위가 원래 단위로 돌아옴
# - 큰 오차에 여전히 민감
# - 해석이 비교적 쉬움
#
# ## 한 줄 설명
# 👉 실제 데이터 단위 기준 평균 오차
#
# ---
#
# #  4️⃣ R² Score (결정계수)
#
# ## 정의
# 모델이 데이터를 얼마나 잘 설명하는지 나타내는 점수
#
# ## 공식 개념
# R² = 1 - (모델 오차 / 평균 예측 오차)
#
# ## 해석 기준
#
# | R² 값 | 의미 |
# |--------|------|
# | 1 | 완벽한 예측 |
# | 0 | 평균 예측과 동일 |
# | 0.8 | 80% 설명 |
# | 음수 | 평균보다 못함 |
#
# ## 한 줄 설명
# 👉 모델의 설명력 점수
#
# ---
#
# # 지표 비교 정리
#
# | 지표 | 클수록 좋음? | 이상치 영향 | 단위 |
# |------|--------------|------------|------|
# | MAE  | ❌ 작을수록 좋음 | 적음 | 원래 단위 |
# | MSE  | ❌ 작을수록 좋음 | 매우 큼 | 제곱 단위 |
# | RMSE | ❌ 작을수록 좋음 | 큼 | 원래 단위 |
# | R²   | ✅ 클수록 좋음 | 간접 영향 | 비율 |
#
# ---
#
# # 🎯 언제 무엇을 쓰는가?
#
# - 이상치가 많을 때 → MAE
# - 큰 오차를 강하게 벌주고 싶을 때 → MSE / RMSE
# - 모델 설명력을 보고 싶을 때 → R²
#
# ---
#
# # 💻 파이썬 코드 예시
#
# ```python
# from sklearn.metrics import mean_absolute_error
# from sklearn.metrics import mean_squared_error
# from sklearn.metrics import r2_score
# import numpy as np
#
# mae = mean_absolute_error(y_true, y_pred)
# mse = mean_squared_error(y_true, y_pred)
# rmse = np.sqrt(mse)
# r2 = r2_score(y_true, y_pred)
#
# print("MAE:", mae)
# print("MSE:", mse)
# print("RMSE:", rmse)
# print("R2:", r2)

# %%
from sklearn.linear_model import Ridge,Lasso
from sklearn.model_selection import GridSearchCV   #실전..... 옵튜나

r_model = Ridge()
l_model = Lasso()

r_param = {'alpha':[0.001,0.01,0.1,1,10,100]}

r_grid = GridSearchCV(r_model, param_grid=r_param, cv=5)
l_grid = GridSearchCV(l_model, param_grid=r_param, cv=5)

r_grid.fit(X_train,y_train)
r_pred = r_grid.best_estimator_.predict(X_test)
r_mae = mean_absolute_error(y_test,r_pred)
r_r2 = r2_score(y_test,r_pred)

print('Ridge param(alpha): ',r_grid.best_params_)
print('Ridge score: ',r_grid.best_score_)
print('Ridge mae: ',r_mae)
print('Ridge r2: ',r_r2)


l_grid.fit(X_train,y_train)
l_pred = l_grid.best_estimator_.predict(X_test)
l_mae = mean_absolute_error(y_test,l_pred)
l_r2 = r2_score(y_test,l_pred)

print('Ridge param(alpha): ',l_grid.best_params_)
print('Ridge score: ',l_grid.best_score_)
print('Ridge mae: ',l_mae)
print('Ridge r2: ',l_r2)
# Out:
# Ridge param(alpha):  {'alpha': 0.1}
# Ridge score:  0.9247421914054955
# Ridge mae:  2.3817692225974714
# Ridge r2:  0.9281689900962815
# Ridge param(alpha):  {'alpha': 0.001}
# Ridge score:  0.9247418619524866
# Ridge mae:  2.3817914293491893
# Ridge r2:  0.928166456143585

# %%
X_test
# Out:
#      Distance_km  Riders_Available  Weather_Index  Rush_Hour
# 603     1.076566                14              5          1
# 4       1.514121                23              4          0
# 44      2.182070                22              5          0
# 506     6.421027                23              8          1
# 252     6.032388                15              8          1
# ..           ...               ...            ...        ...
# 150     6.403728                29              4          1
# 402     3.784140                25              3          0
# 721     1.678015                29              8          0
# 675     6.885461                14              0          0
# 493     1.722788                27              8          0
#
# [250 rows x 4 columns]

# %%
X_train
# Out:
#      Distance_km  Riders_Available  Weather_Index  Rush_Hour
# 331     5.426000                24              6          0
# 182     6.510509                 9              3          0
# 906     5.813383                 9              0          0
# 267     5.066147                21              3          0
# 72      0.535894                17              8          0
# ..           ...               ...            ...        ...
# 424     0.874132                19              2          0
# 65      4.027525                 8             10          0
# 45      4.806395                14             10          0
# 629     2.140840                19             10          0
# 578     3.698756                 6              4          0
#
# [750 rows x 4 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_model = PolynomialFeatures(degree=2, include_bias=False)

X_train_poly = poly_model.fit_transform(X_train)
X_test_poly = poly_model.transform(X_test)

model = LinearRegression()

model.fit(X_train_poly,y_train)

pred = model.predict(X_test_poly)

r2_score(y_test,pred)
# Out:
# 0.9262844335853735

# %%
a,b,c,d,a2,b2,c2,d2,ab,ac,ad,bc,bd
